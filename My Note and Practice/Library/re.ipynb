# %%
import re

# %%
text = "My phone number is 01712345678"
pattern = r"\d+"   # means: one or more digits
result = re.findall(pattern, text)
print(result)
# Out:
# ['01712345678']

# %%
text =  'a'
result = re.match(r'ab*', text)
result
# Out:
# <re.Match object; span=(0, 1), match='a'>
