# %%
import pandas as pd

# %% [markdown]
# ##### Example 1

# %%
df = pd.DataFrame({
    'Fruit': ['Apple', 'Banana', 'Orange', 'Apple', 'Orange', 'Banana'],
    'Price': [1.2, 0.5, 0.8, 1.3, 0.9, 0.6]
})
df
# Out:
#     Fruit  Price
# 0   Apple    1.2
# 1  Banana    0.5
# 2  Orange    0.8
# 3   Apple    1.3
# 4  Orange    0.9
# 5  Banana    0.6

# %%
# !pip install category_encoders

# %%
from category_encoders import BinaryEncoder as be

# %%
be = be(cols='Fruit')
be.fit_transform(df)
# Out:
#    Fruit_0  Fruit_1  Price
# 0        0        1    1.2
# 1        1        0    0.5
# 2        1        1    0.8
# 3        0        1    1.3
# 4        1        1    0.9
# 5        1        0    0.6

# %% [markdown]
# ##### Example2

# %%
df2 = pd.DataFrame({
    'Employee id': [10, 20, 15, 25, 30],
    'Gender': ['M', 'F', 'F', 'M', 'F'],
    'Remarks': ['Good', 'Nice', 'Good', 'Great', 'Nice']
})
df2
# Out:
#    Employee id Gender Remarks
# 0           10      M    Good
# 1           20      F    Nice
# 2           15      F    Good
# 3           25      M   Great
# 4           30      F    Nice

# %%
from category_encoders import BinaryEncoder as be

# %%
be2 = be(cols=['Gender' , 'Remarks'])
be2.fit_transform(df2)
# Out:
#    Employee id  Gender_0  Gender_1  Remarks_0  Remarks_1
# 0           10         0         1          0          1
# 1           20         1         0          1          0
# 2           15         1         0          0          1
# 3           25         0         1          1          1
# 4           30         1         0          1          0
