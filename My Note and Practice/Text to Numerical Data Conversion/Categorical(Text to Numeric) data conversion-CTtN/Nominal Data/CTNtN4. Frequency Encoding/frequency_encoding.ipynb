# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Brand' : ["Nike", "Adidas", "Nike", "Puma", "Adidas", "Nike", "Reebok"]
})
df
# Out:
#     Brand
# 0    Nike
# 1  Adidas
# 2    Nike
# 3    Puma
# 4  Adidas
# 5    Nike
# 6  Reebok

# %% [markdown]
# <div style="text-align: center; font-size:40px;">Manual Method</div>

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Nike      3
# Adidas    2
# Puma      1
# Reebok    1
# Name: count, dtype: int64

# %%
df['Brand_freq'] = df['Brand'].map(df['Brand'].value_counts())

# %%
df
# Out:
#     Brand  Brand_freq
# 0    Nike           3
# 1  Adidas           2
# 2    Nike           3
# 3    Puma           1
# 4  Adidas           2
# 5    Nike           3
# 6  Reebok           1

# %% [markdown]
# <div style="text-align: center; font-size:40px;">Automatic Method</div>

# %%
import category_encoders as ce
from category_encoders import CountEncoder

# %%
df_a = pd.DataFrame({
    'Brand' : ["Nike", "Adidas", "Nike", "Puma", "Adidas", "Nike", "Reebok"]
})
df_a
# Out:
#     Brand
# 0    Nike
# 1  Adidas
# 2    Nike
# 3    Puma
# 4  Adidas
# 5    Nike
# 6  Reebok

# %%
encoder = CountEncoder(cols=['Brand'])

# %%
df_encoder = encoder.fit_transform(df_a)

# %%
df_encoder
# Out:
#    Brand
# 0      3
# 1      2
# 2      3
# 3      1
# 4      2
# 5      3
# 6      1
