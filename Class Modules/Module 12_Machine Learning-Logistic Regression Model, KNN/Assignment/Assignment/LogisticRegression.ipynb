# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# **load the csv**

# %%
df = pd.read_csv('titanic_full.csv')

# %%
df
# Out:
#       Pclass      Fare  Survived
# 0          3    7.2500         0
# 1          1   71.2833         1
# 2          3    7.9250         1
# 3          1   53.1000         1
# 4          3    8.0500         0
# ...      ...       ...       ...
# 1303       3    8.0500         0
# 1304       1  108.9000         1
# 1305       3    7.2500         0
# 1306       3    8.0500         0
# 1307       3   22.3583         0
#
# [1308 rows x 3 columns]

# %% [markdown]
# **Check the null value**

# %%
df.isnull().sum()
# Out:
# Pclass      0
# Fare        0
# Survived    0
# dtype: int64

# %% [markdown]
# **Plot the data**

# %%
plt.scatter(df['Fare'], df['Survived'], marker='+',color='red')

# %%
# from sklearn.decomposition import PCA

# pca = PCA(n_components=1)
# df['X_combined'] = pca.fit_transform(df[['Pclass','Fare']])

# plt.figure(figsize=(8,6))
# plt.scatter(df['X_combined'], df['Survived'], marker = '+', color = 'red')

# %% [markdown]
# **Separate the Features a target in x and y**

# %%
x = df[['Pclass','Fare']]
y = df["Survived"]

# %% [markdown]
# **Split the train and test data**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, train_size = 0.8, random_state = 42)

# %% [markdown]
# **Make the model Binary logistic regression model**

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Check the model score**

# %%
model.score(X_test, Y_test)
# Out:
# 0.6145038167938931
