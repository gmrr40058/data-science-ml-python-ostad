# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
w1 = 'pink'
w2= 'red'

w1 = nlp.vocab[w1]
w2 = nlp.vocab[w2]

# %%
w1

# %%
w1.similarity(w2)
# Out:
# 0.7830261588096619
